# %%
import pandas as pd

# %%
##from here https://www.kaggle.com/s903124/nhl-playbyplay-data-from-2007
## all play by play info 2007-2020 or 2021

nhl_df = pd.read_csv("/Users/joejohns/Downloads/nhl_pbp20072008.csv")
nhl_df2 = pd.read_csv("/Users/joejohns/Downloads/nhl_shifts20072008.csv")

# %%
nhl_df.loc[-10:, :]
# Out:
#         Game_Id        Date  Period Event  \
# 0         20001  2007-09-29       1  STOP
# 1         20001  2007-09-29       1  PSTR
# 2         20001  2007-09-29       1   FAC
# 3         20001  2007-09-29       1  SHOT
# 4         20001  2007-09-29       1   HIT
# ...         ...         ...     ...   ...
# 382953    30416  2008-06-04       3  STOP
# 382954    30416  2008-06-04       3   FAC
# 382955    30416  2008-06-04       3  SHOT
# 382956    30416  2008-06-04       3  PEND
# 382957    30416  2008-06-04       3  GEND
#
#                                               Description Time_Elapsed  \
# 0                                             RINK REPAIR         0:00
# 1                      Period Start- Local time: 5:31 BST         0:00
# 2       ANA won Neu. Zone - ANA #19 MCDONALD vs L.A #1...         0:00
# 3       L.A ONGOAL - 11 KOPITAR, Wrist, Off. Zone, 22 ft.         0:17
# 4               ANA #10 PERRY HIT L.A #4 BLAKE, Off. Zone         0:25
# ...

# %%
nhl_df["Event"].value_counts()
# Out:
# FAC      74438
# SHOT     69945
# STOP     53321
# HIT      51753
# BLOCK    31957
# MISS     28925
# GIVE     22245
# TAKE     18022
# PENL     14650
# GOAL      7490
# PSTR      4393
# PEND      4389
# GEND      1265
# SOC        159
# EISTR        3
# EIEND        3
# Name: Event, dtype: int64

# %%
nhl_df.loc[nhl_df["Event"]=='GOAL', ['Date', 'Period', 'Event', 'Description', 'Time_Elapsed',
       'Seconds_Elapsed', 'Strength', 'Ev_Zone', 'Type', 'Ev_Team',
       'Home_Zone', 'xC', 'yC']]
# Out:
#               Date  Period Event  \
# 36      2007-09-29       1  GOAL
# 131     2007-09-29       2  GOAL
# 175     2007-09-29       3  GOAL
# 227     2007-09-29       3  GOAL
# 258     2007-09-29       3  GOAL
# ...            ...     ...   ...
# 382680  2008-06-04       1  GOAL
# 382799  2008-06-04       2  GOAL
# 382848  2008-06-04       2  GOAL
# 382900  2008-06-04       3  GOAL
# 382947  2008-06-04       3  GOAL
#
#                                               Description Time_Elapsed  \
# 36      L.A #13 CAMMALLERI(1), Wrist, Off. Zone, 27 ft...         8:35
# 131     L.A #4 BLAKE(1), Slap, Off. Zone, 21 ft.Assist...        10:15
# 175     L.A #13 CAMMALLERI(2), Slap, Off. Zone, 27 ft....         1:10
# 227     ANA #54 RYAN(1), Slap, Off. Zone, 15 ft.Assist...        13:09
# 258     L.A #26 HANDZUS(1), Tip-In, Off. Zone, 15 ft.A...        19:34
# ...                                                   ...          ...
# ...

# %%
nhl_df2.head(50)
# Out:
#     Game_Id  Period Team               Player  Player_Id  Start     End  \
# 0     20001       1  ANA          COREY PERRY  8470621.0    0.0    39.0
# 1     20001       1  ANA         CHRIS KUNITZ  8470543.0    0.0    39.0
# 2     20001       1  ANA        ANDY MCDONALD  8468434.0    0.0    39.0
# 3     20001       1  ANA       SEAN O'DONNELL  8458637.0    0.0    39.0
# 4     20001       1  ANA        CHRIS PRONGER  8459424.0    0.0    39.0
# 5     20001       1  ANA       ILYA BRYZGALOV  8468524.0    0.0  1200.0
# 6     20001       1  L.A            ROB BLAKE  8445550.0    0.0    71.0
# 7     20001       1  L.A         ANZE KOPITAR  8471685.0    0.0    41.0
# 8     20001       1  L.A      MIKE CAMMALLERI  8469500.0    0.0    41.0
# 9     20001       1  L.A    LUBOMIR VISNOVSKY  8468598.0    0.0    76.0
# 10    20001       1  L.A         DUSTIN BROWN  8470606.0    0.0    41.0
# 11    20001       1  L.A     JONATHAN BERNIER  8473541.0    0.0   493.0
# ...
