# %%
file_name = "/Users/joejohns/Downloads/nhl odds 2017-18.xlsx"
sheet =  1 # sheet name or sheet number or list of sheet numbers and names

import pandas as pd
df = pd.read_excel(io=file_name) #, sheet_name=sheet)
df.head(10)  # print first 5 rows of the dataframe
# Out:
#    Date  Rot VH          Team  1st  2nd  3rd  Final  Open  Close  Puck Line  \
# 0  1004    1  V       Toronto    3    1    3      7  -110   -105        1.5
# 1  1004    2  H      Winnipeg    0    0    2      2  -110   -115       -1.5
# 2  1004    3  V      St.Louis    2    1    1      5   165    160        1.5
# 3  1004    4  H    Pittsburgh    1    1    2      4  -185   -180       -1.5
# 4  1004    5  V       Calgary    0    0    0      0   132    135        1.5
# 5  1004    6  H      Edmonton    1    0    2      3  -152   -155       -1.5
# 6  1004    7  V  Philadelphia    2    1    2      5   140    130        1.5
# 7  1004    8  H       SanJose    2    0    1      3  -160   -150       -1.5
# 8  1005   51  V      Montreal    1    0    1      3  -130   -125       -1.5
# 9  1005   52  H       Buffalo    1    1    0      2   110    105        1.5
#
#    Unnamed: 11  Open OU  Unnamed: 13  Close OU  Unnamed: 15
# 0         -295      5.5         -125       6.0         -115
# 1          235      5.5          105       6.0         -105
# 2         -185      5.5         -110       5.5          105
# 3          160      5.5         -110       5.5         -125
# 4         -230      5.5         -106       5.5         -105
# 5          190      5.5         -114       5.5         -115
# 6         -240      5.5          104       5.0         -135
# 7          200      5.5         -124       5.0          115
# 8          220      5.0         -120       5.0         -135
# 9         -270      5.0          100       5.0          115

# %%
df.shape
# Out:
# (2710, 16)
