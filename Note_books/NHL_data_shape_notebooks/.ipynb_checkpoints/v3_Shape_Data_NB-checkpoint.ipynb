# %% [markdown]
# IMPORT DATA

# %%
##grab all of the Kaggle Data

Kaggle_files = ['game.csv',
'game_teams_stats.csv',
'game_scratches.csv',
'game_officials.csv',
'game_skater_stats.csv',
'game_goalie_stats.csv'] 


Kaggle_path = "/Users/joejohns/data_bootcamp/Final_Project_NHL_prediction/Data/Kaggle_Data_Ellis/"
mp_path = "/Users/joejohns/data_bootcamp/Final_Project_NHL_prediction/Data/Money_Puck_Data/"
betting_path = "/Users/joejohns/data_bootcamp/Final_Project_NHL_prediction/Data/Betting_Data/"


import pandas as pd
import numpy as np

# %%
df_game = pd.read_csv(Kaggle_path+'game.csv')
df_game_team_stats = pd.read_csv(Kaggle_path+'game_teams_stats.csv')
df_game_skater_stats = pd.read_csv(Kaggle_path+'game_skater_stats.csv')
df_game_goalie_stats = pd.read_csv(Kaggle_path+'game_goalie_stats.csv')

##more subtle features:
df_game_scratches = pd.read_csv(Kaggle_path+'game_scratches.csv')
df_game_officials = pd.read_csv(Kaggle_path+'game_officials.csv')
df_team_info = pd.read_csv(Kaggle_path+'team_info.csv')

# %%
## grab all the moneypuck data 

df_mp_teams = pd.read_csv(mp_path+'all_teams.csv')

# %%
## grab all betting data 
df1 = pd.read_excel(io = betting_path+'nhl odds 2007-08.xlsx')
df2 = pd.read_excel(io = betting_path+'nhl odds 2008-09.xlsx')
df3 = pd.read_excel(io = betting_path+'nhl odds 2009-10.xlsx')
df4 = pd.read_excel(io = betting_path+'nhl odds 2010-11.xlsx')
df5 = pd.read_excel(io = betting_path+'nhl odds 2011-12.xlsx')
df6 = pd.read_excel(io = betting_path+'nhl odds 2012-13.xlsx')
df7 = pd.read_excel(io = betting_path+'nhl odds 2013-14.xlsx')
df8 = pd.read_excel(io = betting_path+'nhl odds 2014-15.xlsx')
df9 = pd.read_excel(io = betting_path+'nhl odds 2015-16.xlsx')
df10 = pd.read_excel(io = betting_path+'nhl odds 2016-17.xlsx')
df11 = pd.read_excel(io = betting_path+'nhl odds 2017-18.xlsx')
df12 = pd.read_excel(io = betting_path+'nhl odds 2018-19.xlsx')
df13 = pd.read_excel(io = betting_path+'nhl odds 2019-20.xlsx')

# %%
df1['season'] = 20072008
df2['season'] = 20082009
df3['season'] = 20092010
df4['season'] = 20102011
df5['season'] = 20112012
df6['season'] = 20122013
df7['season'] = 20132014
df8['season'] = 20142015
df9['season'] = 20152016
df10['season'] = 20162017
df11['season'] = 20172018
df12['season'] = 20182019
df13['season'] = 20192020

# %%
##omit 2007-2008

df_betting = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13])

# %%
##drop diplicates here 

df_game.drop_duplicates(inplace = True)

# %%
## restrict data sets 
df_betting = df_betting.loc[:, ['Date', 'season','VH', 'Team', 'Open']].copy()



df_mp_teams_all = df_mp_teams.loc[df_mp_teams['situation'] == 'all', :].copy()

# %% [markdown]
# FIX SEASONS IN df_mp ... then all 3 of df_games, df_mp_teams, df_betting have same season format for cutting down seasons

# %%
#df_mp_teams_all['']
def fix_mp_season(n):
    return int(str(n)+str(n+1))

#test fix_mp_season(2008)
df_mp_teams['season'] = df_mp_teams['season'].map(fix_mp_season)

# %%
##restrict seasons 
seasons = []
for n in range(2008,2020):
    seasons.append(int(str(n)+str(n+1)))

print(seasons)
# Out:
# [20082009, 20092010, 20102011, 20112012, 20122013, 20132014, 20142015, 20152016, 20162017, 20172018, 20182019, 20192020]

# %%
for seas in seasons:
    print(seas, len(df_mp_teams.loc[df_mp_teams['season']==seas])/10, len(df_game.loc[df_game['season']==seas]), len(df_betting.loc[df_betting['season']==seas])/2)
# Out:
# 20082009 1314.0 1230 1317.0
# 20092010 1318.0 1230 1318.0
# 20102011 1318.0 1319 1319.0
# 20112012 1316.0 1316 1315.0
# 20122013 806.0 806 806.0
# 20132014 1323.0 1323 1323.0
# 20142015 1319.0 1319 1319.0
# 20152016 1321.0 1321 1321.0
# 20162017 1317.0 1323 1317.0
# 20172018 1355.0 1363 1355.0
# 20182019 1358.0 1360 1358.0
# 20192020 1212.0 1215 1212.0

# %%
##they match up starting 2013-14 ... but that was short so let's go with 2013-14

# %% [markdown]
# CUT DOWN SEASONS TO 2008-09 to 2019-20

# %%
#restrict seasons: #betting is done already

df_game = df_game.loc[df_game['season'].isin(seasons), :].copy()
df_mp_teams = df_mp_teams.loc[df_mp_teams['season'].isin(seasons), :].copy()

# %% [markdown]
# FIX TEAM NAMES

# %%
##fix names of teams
fix_dic = {'Arizonas': 'Arizona', 'NYIslanders': 'NY Islanders', 'NYRangers': 'NY Rangers',
           'NewJersey':'New Jersey', 'LosAngeles': 'Los Angeles', 'SanJose': 'San Jose', 'St.Louis': 'St Louis', 
           'Tampa': 'Tampa Bay',  'TampaBay': 'Tampa Bay', 'WinnipegJets': 'Winnipeg'}



def fix_bet_names(s):
    if s in fix_dic.keys():
        return fix_dic[s]
    else:
        return s
  
def fix_mp_names(s):
    if s == 'L.A':
        return 'LAK'
    elif s == 'S.J':
        return 'SJS'
    elif s == 'N.J':
        return 'NJD'
    elif s == 'T.B':
        return 'TBL'
    else:
        return s

# %%
df_betting['Team'] = df_betting['Team'].apply(fix_bet_names)

df_mp_teams['playerTeam']  = df_mp_teams['playerTeam'].apply(fix_mp_names)  
df_mp_teams['opposingTeam']  = df_mp_teams['opposingTeam'].apply(fix_mp_names)

# %% [markdown]
# ATTACH team_id to betting

# %%
def attach_bet_team_id(s):
    return df_team_info.loc[df_team_info['shortName'] == s, 'team_id'].array[0]

# %%
df_betting['team_id'] = df_betting['Team'].map(attach_bet_team_id)

# %% [markdown]
# put proper dates on df_game and df_betting

# %% [markdown]
# Attach game_id to df_betting;
# To do this we need to attach a smilar month day code to df_game so we can match them

# %%
'20082009'[4:]
# Out:
# '2009'

# %%
#restrict seasons: #betting is done already
def bet_mp_date(date, season):
    d = str(date)
    s = str(season)
    if len(d) == 3:
        d = "0"+d 
    if (900 < date):
        y= s[:4]
    else:
        y = s[4:]
    return int(y+d)

# %%
df_betting['mp_date'] = np.vectorize(bet_mp_date)(df_betting['Date'], df_betting['season'])

# %%
df_betting.iloc[2000:2050, :]
# Out:
#       Date    season VH          Team  Open  team_id   mp_date
# 2000   304  20072008  V    Pittsburgh  -115        5  20080304
# 2001   304  20072008  H     Tampa Bay  -105       14  20080304
# 2002   304  20072008  V    New Jersey  -130        1  20080304
# 2003   304  20072008  H       Toronto   110       10  20080304
# 2004   304  20072008  V       Chicago   171       16  20080304
# 2005   304  20072008  H     Minnesota  -201       30  20080304
# 2006   304  20072008  V   Los Angeles   130       26  20080304
# 2007   304  20072008  H      St Louis  -150       19  20080304
# 2008   304  20072008  V      Columbus   155       29  20080304
# 2009   304  20072008  H       Calgary  -175       20  20080304
# 2010   304  20072008  V     Nashville  -110       18  20080304
# 2011   304  20072008  H      Edmonton  -110       22  20080304
# 2012   304  20072008  V     Vancouver   130       23  20080304
# 2013   304  20072008  H      Colorado  -150       21  20080304
# 2014   305  20072008  V      Carolina  -135       12  20080305
# 2015   305  20072008  H       Atlanta   115       11  20080305
# 2016   305  20072008  V    Washington   110       15  20080305
# 2017   305  20072008  H       Buffalo  -130        7  20080305
# 2018   305  20072008  V      St Louis   200       19  20080305
# 2019   305  20072008  H       Detroit  -240       17  20080305
# 2020   305  20072008  V       Phoenix   170       27  20080305
# 2021   305  20072008  H        Dallas  -200       25  20080305
# 2022   305  20072008  V       Anaheim   170       24  20080305
# 2023   305  20072008  H       Chicago  -200       16  20080305
# 2024   305  20072008  V        Ottawa   130        9  20080305
# 2025   305  20072008  H      San Jose  -150       28  20080305
# 2026   306  20072008  V       Toronto   135       10  20080306
# 2027   306  20072008  H        Boston  -155        6  20080306
# 2028   306  20072008  V     Tampa Bay   150       14  20080306
# 2029   306  20072008  H  Philadelphia  -170        4  20080306
# 2030   306  20072008  V     Minnesota  -110       30  20080306
# 2031   306  20072008  H      Carolina  -110       12  20080306
# 2032   306  20072008  V    NY Rangers  -140        3  20080306
# 2033   306  20072008  H  NY Islanders   120        2  20080306
# 2034   306  20072008  V    Pittsburgh  -115        5  20080306
# 2035   306  20072008  H       Florida  -105       13  20080306
# 2036   306  20072008  V      Montreal  -115        8  20080306
# 2037   306  20072008  H       Phoenix  -105       27  20080306
# 2038   306  20072008  V       Anaheim  -105       24  20080306
# 2039   306  20072008  H      Colorado  -115       21  20080306
# 2040   306  20072008  V     Nashville   115       18  20080306
# 2041   306  20072008  H     Vancouver  -135       23  20080306
# 2042   306  20072008  V        Ottawa  -120        9  20080306
# 2043   306  20072008  H   Los Angeles   100       26  20080306
# 2044   307  20072008  V      Edmonton   125       22  20080307
# 2045   307  20072008  H      Columbus  -145       29  20080307
# 2046   307  20072008  V     Tampa Bay   190       14  20080307
# 2047   307  20072008  H    New Jersey  -220        1  20080307
# 2048   307  20072008  V     Minnesota  -135       30  20080307
# 2049   307  20072008  H       Atlanta   115       11  20080307

# %%
## do mp style date for df_games

df_game['date_time_GMT'] = pd.to_datetime(df_game['date_time_GMT'])

# %%
def to_bet_date(date_time):
    d = str(date_time.day)
    m = str(date_time.month)
    #y = str(date_time.year)
    if len(d) ==1:
        d = "0"+d
    if len(m) ==1:
        m = "0"+m
    return int(m+d)

# %%
def to_mp_date(date_time):
    d = str(date_time.day)
    m = str(date_time.month)
    y = str(date_time.year)
    if len(d) ==1:
        d = "0"+d
    if len(m) ==1:
        m = "0"+m
    return int(y+m+d)

# %%
test = df_game['date_time_GMT'][0]
print(test, to_bet_date(test), to_mp_date(test))
# Out:
# 2016-10-19 00:30:00+00:00 1019 20161019

# %%
#test to_bet_date(18, 9)  to_bet_date(8, 10)

# %%
df_game['mp_date'] = df_game['date_time_GMT'].apply(to_mp_date)

# %%
df_mp_teams.iloc[700: 750, :]
# Out:
#     team    season name      gameId playerTeam opposingTeam home_or_away  \
# 700  NYR  20092010  NYR  2009020861        NYR          NJD         HOME
# 701  NYR  20092010  NYR  2009020861        NYR          NJD         HOME
# 702  NYR  20092010  NYR  2009020861        NYR          NJD         HOME
# 703  NYR  20092010  NYR  2009020861        NYR          NJD         HOME
# 704  NYR  20092010  NYR  2009020861        NYR          NJD         HOME
# 705  NYR  20092010  NYR  2009020884        NYR          NSH         HOME
# 706  NYR  20092010  NYR  2009020884        NYR          NSH         HOME
# 707  NYR  20092010  NYR  2009020884        NYR          NSH         HOME
# 708  NYR  20092010  NYR  2009020884        NYR          NSH         HOME
# 709  NYR  20092010  NYR  2009020884        NYR          NSH         HOME
# 710  NYR  20092010  NYR  2009020901        NYR          PIT         AWAY
# 711  NYR  20092010  NYR  2009020901        NYR          PIT         AWAY
# 712  NYR  20092010  NYR  2009020901        NYR          PIT         AWAY
# 713  NYR  20092010  NYR  2009020901        NYR          PIT         AWAY
# 714  NYR  20092010  NYR  2009020901        NYR          PIT         AWAY
# 715  NYR  20092010  NYR  2009020916        NYR          TBL         HOME
# 716  NYR  20092010  NYR  2009020916        NYR          TBL         HOME
# 717  NYR  20092010  NYR  2009020916        NYR          TBL         HOME
# 718  NYR  20092010  NYR  2009020916        NYR          TBL         HOME
# 719  NYR  20092010  NYR  2009020916        NYR          TBL         HOME
# 720  NYR  20092010  NYR  2009020928        NYR          OTT         AWAY
# 721  NYR  20092010  NYR  2009020928        NYR          OTT         AWAY
# 722  NYR  20092010  NYR  2009020928        NYR          OTT         AWAY
# 723  NYR  20092010  NYR  2009020928        NYR          OTT         AWAY
# 724  NYR  20092010  NYR  2009020928        NYR          OTT         AWAY
# 725  NYR  20092010  NYR  2009020942        NYR          PIT         HOME
# 726  NYR  20092010  NYR  2009020942        NYR          PIT         HOME
# 727  NYR  20092010  NYR  2009020942        NYR          PIT         HOME
# 728  NYR  20092010  NYR  2009020942        NYR          PIT         HOME
# 729  NYR  20092010  NYR  2009020942        NYR          PIT         HOME
# 730  NYR  20092010  NYR  2009020958        NYR          WSH         AWAY
# 731  NYR  20092010  NYR  2009020958        NYR          WSH         AWAY
# 732  NYR  20092010  NYR  2009020958        NYR          WSH         AWAY
# 733  NYR  20092010  NYR  2009020958        NYR          WSH         AWAY
# 749                   0.000                                0.000
#
#      scoreFlurryAdjustedTotalShotCreditAgainst  playoffGame
# 700                                      0.779            0
# 701                                      3.290            0
# 702                                      2.166            0
# 703                                      0.084            0
# 704                                      0.261            0
# 705                                      0.000            0
# 706                                      3.763            0
# 707                                      1.985            0
# 708                                      1.731            0
# 709                                      0.047            0
# 710                                      0.000            0
# 711                                      2.415            0
# 712                                      1.744            0
# 713                                      0.563            0
# 714                                      0.108            0
# 715                                      1.145            0
# 716                                      2.748            0
# 717                                      1.471            0
# 718                                      0.069            0
# 719                                      0.063            0
# 720                                      0.000            0
# 721                                      1.853            0
# 722                                      1.187            0
# 723                                      0.422            0
# 724                                      0.244            0
# 725                                      1.306            0
# 726                                      5.738            0
# 727                                      2.285            0
# 728                                      1.788            0
# 729                                      0.359            0
# 730                                      0.551            0
# 731                                      1.976            0
# 732                                      1.190            0
# 733                                      0.184            0
# 734                                      0.052            0
# 735                                      0.575            0
# 736                                      3.109            0
# 737                                      2.511            0
# 738                                      0.022            0
# 739                                      0.000            0
# 740                                      0.000            0
# 741                                      3.091            0
# 742                                      2.450            0
# 743                                      0.281            0
# 744                                      0.360            0
# 745                                      0.188            0
# 746                                      2.274            0
# 747                                      1.507            0
# 748                                      0.579            0
# 749                                      0.000            0
#
# [50 rows x 111 columns]

# %%
def to_mp_date(date_time):
    d = str(date_time.day)
    m = str(date_time.month)
    if len(d) ==1:
        d = "0"+d
    return int(m+d)

# %%
def perc_null(X):
    
    total = X.isnull().sum().sort_values(ascending=False)
    data_types = X.dtypes
    percent = (X.isnull().sum()/X.isnull().count()).sort_values(ascending=False)

    missing_data = pd.concat([total, data_types, percent], axis=1, keys=['Total','Type', 'Percent'])
    return missing_data

# %%
df_game.drop(columns = ['home_rink_side_start'], inplace = True)

# %%
perc_null(df_game)
# Out:
#                         Total                 Type  Percent
# game_id                     0                int64      0.0
# season                      0                int64      0.0
# type                        0               object      0.0
# date_time_GMT               0  datetime64[ns, UTC]      0.0
# away_team_id                0                int64      0.0
# home_team_id                0                int64      0.0
# away_goals                  0                int64      0.0
# home_goals                  0                int64      0.0
# outcome                     0               object      0.0
# venue                       0               object      0.0
# venue_link                  0               object      0.0
# venue_time_zone_id          0               object      0.0
# venue_time_zone_offset      0                int64      0.0
# venue_time_zone_tz          0               object      0.0
# bet_date                    0                int64      0.0

# %%
#test

len(df_game.loc[(df_game['bet_date'] == 1004)&(df_game['season'] == 20082009)&(df_game['home_team_id'] == 4),  :]['game_id'].values)
# Out:
# 0

# %%
df_betting.loc[df_betting['VH']=='N',:]
# Out:
#       Date    season VH        Team  Open  team_id
# 2164   801  20192020  N    Montreal  -110        8
# 2165   801  20192020  N  Pittsburgh  -120        5
# 2166   801  20192020  N  NY Rangers   120        3
# 2167   801  20192020  N    Carolina  -150       12
# 2168   801  20192020  N     Florida   110       13
# ...    ...       ... ..         ...   ...      ...
# 2419   925  20192020  N      Dallas   140       25
# 2420   926  20192020  N      Dallas   145       25
# 2421   926  20192020  N   Tampa Bay  -166       14
# 2422   928  20192020  N   Tampa Bay  -161       14
# 2423   928  20192020  N      Dallas   141       25
#
# [260 rows x 6 columns]

# %%
def assign_game_id(date, season, team_id): #this is assuming it is home team and these are from df_betting 
    h = df_game.loc[(df_game['bet_date'] == date)&(df_game['season'] == season)&(df_game['home_team_id'] == team_id),  :]['game_id'].values
    a = df_game.loc[(df_game['bet_date'] == date)&(df_game['season'] == season)&(df_game['away_team_id'] == team_id),  :]['game_id'].values
    if len(h) == 1:
        return h[0]
    elif len(a) == 1:
        return a[0]
    else:
        return 314159

# %%
df_game.loc[(df_game['bet_date'] == 1009)&(df_game['season'] == 20082009)&(df_game['away_team_id'] == 6),  :]['game_id'].values


#1009	20082009	V	Boston	120	6	314159
# Out:
# array([], dtype=int64)

# %%
df_mp_teams.loc[(df_mp_teams['gameDate']==20081010)&(df_mp_teams['situation']=='all'), :]

# %%
df_betting.loc[(df_betting['Date'] == 1010)& (df_betting['season'] == 20082009), :]

# %%
df_game.loc[(df_game['season'] == 20082009) & (df_game['date_time_GMT'].apply(lambda x : x.month) == 10)&(df_game['date_time_GMT'].apply(lambda x : x.day) == 10), :]

# %%
df_game.loc[(df_game['season'] == 20082009) & (df_game['bet_date'] == 1009), :]

# %%
def assign_home_game_id(date, season, team_id): #this is assuming it is home team and these are from df_betting 
    return df_game.loc[(df_game['bet_date'] == date)&(df_game['season'] == season)&(df_game['home_team_id'] == team_id),  :]['game_id'].values[0]

def assign_away_game_id(date, season, team_id):
    return df_game.loc[(df_game['bet_date'] == date)&(df_game['season'] == season)&(df_game['away_team_id'] == team_id),  :]['game_id'].values[0]

# %%
assign_away_game_id(1004, 20082009, 3)

# %%
df_betting_home = df_betting.loc[df_betting['VH'] == 'H', :].copy()
df_betting_away = df_betting.loc[df_betting['VH'] == 'V', :].copy()

# %%
df_betting['game_id'] =  np.vectorize(assign_game_id)(df_betting['Date'], df_betting['season'],  df_betting['team_id'])

# %%
df_betting.shape

# %%
df_game['bet_date']
# Out:
# 0        1019
# 1         207
# 2        1124
# 3         217
# 4        1230
#          ...
# 26295     602
# 26297     604
# 26299     607
# 26301     610
# 26303     613
# Name: bet_date, Length: 7901, dtype: int64

# %%
df_betting['Date']
# Out:
# 0        929
# 1        929
# 2        930
# 3        930
# 4       1003
#         ...
# 2419     925
# 2420     926
# 2421     926
# 2422     928
# 2423     928
# Name: Date, Length: 33190, dtype: int64

# %%
for seas in seasons:
    print(df_betting.loc[(df_betting['game_id'] == 314159)&(df_betting['season'] == seas),:].shape ,df_betting.loc[(df_betting['season'] == seas),:] )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'game_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-4801035fe7c6> in <module>
#       1 for seas in seasons:
# ----> 2     print(df_betting.loc[(df_betting['game_id'] == 314159)&(df_betting['season'] == seas),:].shape ,df_betting.loc[(df_betting['season'] == seas),:] )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'game_id'
